# %% [markdown]
# ## Importing The Libraries

# %%
from imageai.Classification.Custom import ClassificationModelTrainer
import warnings
warnings.simplefilter("ignore")
warnings.filterwarnings("ignore")
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %% [markdown]
# ## Creating an Instance of ClassificationModelTrainer class

# %%
model_trainer_densenet121 = ClassificationModelTrainer()
model_trainer_densenet121.setModelTypeAsDenseNet121()

# %% [markdown]
# ## Specifying the Working Directories

# %%
model_trainer_densenet121.setDataDirectory(r"E:\Docs\courseRelated\AdvTopicsInML\FinalProject\dataset",  # data_directory  
                                           r"E:\Docs\courseRelated\AdvTopicsInML\FinalProject\dataset\train",  # train_subdirectory
                                           r"E:\Docs\courseRelated\AdvTopicsInML\FinalProject\dataset\validation",  # test_subdirectory
                                           r"E:\Docs\courseRelated\AdvTopicsInML\FinalProject\dataset\model\densenet121",  # model_subdirectory
                                           r"E:\Docs\courseRelated\AdvTopicsInML\FinalProject\dataset\json\densenet121"  #json_subdirectory 
                                          )

# %% [markdown]
# ## Training the DenseNet121 Model

# %%
# %%time

model_trainer_densenet121.trainModel(num_objects=12, 
                                     num_experiments=20, 
                                     enhance_data=True, 
                                     batch_size=32, 
                                     show_network_summary=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 112, 112, 64) 0           conv1/bn[0][0]
# ...
