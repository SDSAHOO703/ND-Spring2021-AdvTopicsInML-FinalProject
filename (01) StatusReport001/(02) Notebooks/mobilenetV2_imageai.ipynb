# %% [markdown]
# ## Importing The Libraries

# %%
from imageai.Classification.Custom import ClassificationModelTrainer
import warnings
warnings.simplefilter("ignore")
warnings.filterwarnings("ignore")
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %% [markdown]
# ## Creating an Instance of ClassificationModelTrainer class

# %%
model_trainer_mobilenetV2 = ClassificationModelTrainer()
model_trainer_mobilenetV2.setModelTypeAsMobileNetV2()

# %% [markdown]
# ## Specifying the Working Directories

# %%
model_trainer_mobilenetV2.setDataDirectory(r"E:\Docs\courseRelated\AdvTopicsInML\FinalProject\dataset",  # data_directory  
                                           r"E:\Docs\courseRelated\AdvTopicsInML\FinalProject\dataset\train",  # train_subdirectory
                                           r"E:\Docs\courseRelated\AdvTopicsInML\FinalProject\dataset\validation",  # test_subdirectory
                                           r"E:\Docs\courseRelated\AdvTopicsInML\FinalProject\dataset\model\mobilenetV2",  # model_subdirectory
                                           r"E:\Docs\courseRelated\AdvTopicsInML\FinalProject\dataset\json\mobilenetV2"  #json_subdirectory 
                                          )

# %% [markdown]
# ## Training the MobileNetV2 Model

# %%
# %%time

model_trainer_mobilenetV2.trainModel(num_objects=12, 
                                     num_experiments=20, 
                                     enhance_data=True, 
                                     batch_size=32, 
                                     show_network_summary=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# ...
